# %%
import os, glob
import numpy as np
import pandas as pd
import pickle
import urllib.request, urllib.parse
from hunnae_news_scraper import hunnae_scraper
from hunnae_news_scraper import comment_list_scraper

# %%
hunnae_scraper(20191201,20191201, '서강대', None)
# Out:
# 26 / 26
# 26 / 26 COMPLETE!

# %%
with open('20191201_20191201_서강대_None.p', 'rb') as f :
    xdf = pickle.load(f)

# %%
xdf
# Out:
#                                            url query press  \
# 0  http://v.media.daum.net/v/20191201180218939   서강대  None
# 1  http://v.media.daum.net/v/20191201172104102   서강대  None
# 2  http://v.media.daum.net/v/20191201161154888   서강대  None
# 3  http://v.media.daum.net/v/20191201160809797   서강대  None
# 4  http://v.media.daum.net/v/20191201160601742   서강대  None
# 5  http://v.media.daum.net/v/20191201160323666   서강대  None
# 6  http://v.media.daum.net/v/20191201142951867   서강대  None
# 7  http://v.media.daum.net/v/20191201130832737   서강대  None
#
#                                title       date category  \
# 0        [손호철의 사색] 역사는 더불어민주당을 보고 있다        NaT     사설칼럼
# 1                 인간개발硏 '2020 경제' 포럼        NaT       사회
# 2    과학기술정책연, 2일 '기술규제 정책연구 컨퍼런스' 열어        NaT       경제
# 3  송원학원, 2024년 입시 학종 학생부 교과 성적비중 높아져 2019-12-01       사회
# 4               "중·고교서 경제·금융교육 강화해야" 2019-12-01       경제
# 5               영화 '블랙머니', 그 역설에 대하여 2019-12-01     사설칼럼
# 6           경기도어린이박물관장에 광고전문가 표문송 임용        NaT       문화
# 7        경기도어린이박물관 신임 관장에 표문송 광고 전문가        NaT       사회
#
#                                              content  commentcount
# 0  현행 선거법, 거대 양당의 야합 결과 헌재 판결과 반대로 비례대표 축소해 ‘개악 공...            13
# 1  인간개발연구원(HDI·회장 장만기·사진)은 오는 5일 서울 소공동 롯데호텔 에메랄드...             0
# 2  [서울=뉴시스] 박주연 기자 = 과학기술정책연구원(STEPI)이 2일 오후 1시30...             0
# 3  [대구=뉴시스] 나호용 기자 = 현재 중학교 2학년이 대학입시를 치르는 2024년에...             0
# 4  금융시장 참여자에게 경제 교육이 이뤄져야 파생결합펀드(DLF) 등 사건에서 소비자를...             0
# 5  [성상민의 문화 뒤집기] 론스타에 제기된 의혹 관객들에게 환기시킨 공이 있을지는 몰...             1
# 6  [서울경제] 우리나라 제1호 어린이박물관인 경기도어린이박물관의 신임 관장에 표문송 ...             0
# 7  [수원=뉴시스] 정은아 기자 = 경기문화재단은 신임 경기도어린이박물관장에 20여년간...             0
